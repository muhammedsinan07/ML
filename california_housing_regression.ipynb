# %%
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import fetch_california_housing

# %%
housing_data = fetch_california_housing()

# %%
housing_data
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
# ...

# %%
house_df = pd.DataFrame(housing_data.data,columns=housing_data.feature_names)
house_df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
# dtypes: float64(8)
# memory usage: 1.3 MB

# %%
house_df.describe().T
# Out:
#               count         mean          std         min         25%  \
# MedInc      20640.0     3.870671     1.899822    0.499900    2.563400
# HouseAge    20640.0    28.639486    12.585558    1.000000   18.000000
# AveRooms    20640.0     5.429000     2.474173    0.846154    4.440716
# AveBedrms   20640.0     1.096675     0.473911    0.333333    1.006079
# Population  20640.0  1425.476744  1132.462122    3.000000  787.000000
# AveOccup    20640.0     3.070655    10.386050    0.692308    2.429741
# Latitude    20640.0    35.631861     2.135952   32.540000   33.930000
# Longitude   20640.0  -119.569704     2.003532 -124.350000 -121.800000
#
#                     50%          75%           max
# MedInc         3.534800     4.743250     15.000100
# HouseAge      29.000000    37.000000     52.000000
# AveRooms       5.229129     6.052381    141.909091
# AveBedrms      1.048780     1.099526     34.066667
# Population  1166.000000  1725.000000  35682.000000
# ...

# %%
import matplotlib.pyplot as plt

# %%
house_df.hist(bins=50,figsize=(20,15))
plt.show()

# %%
house_df['MedHouseVal'] = housing_data['target']

# %%
from sklearn.model_selection import train_test_split

# %%
train_set,test_set = train_test_split(house_df,test_size=0.2,random_state=44)

# %%
corr_metrix = train_set.corr()

# %%
corr_metrix
# Out:
#                MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc       1.000000 -0.117786  0.329480  -0.071915    0.003063  0.021565
# HouseAge    -0.117786  1.000000 -0.159565  -0.088422   -0.293683  0.015196
# AveRooms     0.329480 -0.159565  1.000000   0.841511   -0.076719 -0.004829
# AveBedrms   -0.071915 -0.088422  0.841511   1.000000   -0.072274 -0.006605
# Population   0.003063 -0.293683 -0.076719  -0.072274    1.000000  0.073891
# AveOccup     0.021565  0.015196 -0.004829  -0.006605    0.073891  1.000000
# Latitude    -0.080506  0.009746  0.111640   0.077636   -0.109554  0.005617
# Longitude   -0.011589 -0.105635 -0.028394   0.012973    0.099218 -0.000302
# MedHouseVal  0.688052  0.099703  0.158547  -0.049490   -0.022212 -0.022552
#
#              Latitude  Longitude  MedHouseVal
# MedInc      -0.080506  -0.011589     0.688052
# HouseAge     0.009746  -0.105635     0.099703
# AveRooms     0.111640  -0.028394     0.158547
# ...

# %%
corr_metrix['MedHouseVal'].sort_values(ascending=False)
# Out:
# MedHouseVal    1.000000
# MedInc         0.688052
# AveRooms       0.158547
# HouseAge       0.099703
# Population    -0.022212
# AveOccup      -0.022552
# Longitude     -0.040645
# AveBedrms     -0.049490
# Latitude      -0.145670
# Name: MedHouseVal, dtype: float64

# %%
house_df.plot(kind='scatter',x='Longitude',y='Latitude',c='MedHouseVal',cmap='jet',colorbar=True,figsize=(10,7),s=house_df['Population']/100,label='Population',alpha=0.4)
plt.show()

# %%
from pandas.plotting import scatter_matrix

# %%
house_df.plot(kind='scatter',x='MedInc',y='MedHouseVal',alpha=0.1)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X = house_df.iloc[:,:-1]
y = house_df.iloc[:,-1]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train.head()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 15961  3.1908      52.0  5.000000   1.014184       879.0  3.117021     37.71
# 1771   3.6094      42.0  4.900990   0.957096       971.0  3.204620     37.95
# 16414  2.6250      16.0  8.333333   1.666667        20.0  3.333333     37.90
# 5056   1.5143      34.0  3.805981   1.149526      3538.0  2.580598     34.02
# 8589   7.3356      38.0  5.894904   1.057325       750.0  2.388535     33.89
#
#        Longitude
# 15961    -122.43
# 1771     -122.35
# 16414    -121.24
# 5056     -118.35
# 8589     -118.39

# %%
y_train.head()
# Out:
# 15961    2.556
# 1771     1.146
# 16414    1.375
# 5056     1.188
# 8589     4.227
# Name: MedHouseVal, dtype: float64

# %%
X_test.head()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 4712   3.2500      39.0  4.503205   1.073718      1109.0  1.777244     34.06
# 2151   1.9784      37.0  4.988584   1.038813      1143.0  2.609589     36.78
# 15927  4.0132      46.0  4.480296   1.012315      1534.0  3.778325     37.73
# 82     1.5208      52.0  3.908046   1.114943       200.0  2.298851     37.81
# 8161   5.1795      37.0  5.406360   1.024735       711.0  2.512367     33.82
#
#        Longitude
# 4712     -118.36
# 2151     -119.78
# 15927    -122.42
# 82       -122.28
# 8161     -118.13

# %%
y_test.head()
# Out:
# 4712     3.550
# 2151     0.707
# 15927    2.294
# 82       1.125
# 8161     2.254
# Name: MedHouseVal, dtype: float64

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %%
regression_pipeline = Pipeline([
    ('scaler',StandardScaler()),
    ('regressor',LinearRegression())
])

# %%
regression_pipeline
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('regressor', LinearRegression())])

# %%
regression_pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('regressor', LinearRegression())])

# %%
y_pred = regression_pipeline.predict(X_test)

# %%
y_pred
# Out:
# array([2.12567705, 0.93977118, 2.70887192, ..., 2.9460839 , 2.63875476,
#        1.46985176])

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test,y_pred)

# %%
print('R Squared Score',r2)
# Out:
# R Squared Score 0.5965968374812352

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mae = mean_absolute_error(y_test,y_pred)

# %%
print('Mean Absolute Error:',mae)
# Out:
# Mean Absolute Error: 0.5328685121247784

# %%
mse = mean_squared_error(y_test,y_pred)

# %%
print('Mean Squared Error:',mse)
# Out:
# Mean Squared Error: 0.529140234539731

# %%
rmse = np.sqrt(mse)

# %%
print('Root Mean Squared Error',rmse)
# Out:
# Root Mean Squared Error 0.7274202599183852
